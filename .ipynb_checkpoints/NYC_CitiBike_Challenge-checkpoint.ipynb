# %%
import pandas as pd

# %%
# 1. Create a DataFrame for the 201908-citibike-tripdata data. 
bikesharing = pd.read_csv("201908-citibike-tripdata.csv")
citibike = pd.DataFrame(bikesharing)

# %%
# 2. Check the datatypes of your columns. 
citibike.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2344224 entries, 0 to 2344223
# Data columns (total 15 columns):
#  #   Column                   Dtype
# ---  ------                   -----
#  0   tripduration             int64
#  1   starttime                object
#  2   stoptime                 object
#  3   start station id         float64
#  4   start station name       object
#  5   start station latitude   float64
#  6   start station longitude  float64
#  7   end station id           float64
#  8   end station name         object
#  9   end station latitude     float64
#  10  end station longitude    float64
#  11  bikeid                   int64
#  12  usertype                 object
#  13  birth year               int64
#  14  gender                   int64
# dtypes: float64(6), int64(4), object(5)
# memory usage: 268.3+ MB

# %%
# 3. Convert the 'tripduration' column to datetime datatype.
citibike['tripduration'] = pd.to_datetime(citibike['tripduration'], unit = 'm')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\tools\datetimes.py in _convert_listlike_datetimes(arg, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     455             try:
# --> 456                 values, tz = conversion.datetime_to_datetime64(arg)
#     457                 dta = DatetimeArray(values, dtype=tz_to_dtype(tz))
#
# pandas\_libs\tslibs\conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'int'>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-50-11503e3eca9e> in <module>
#       1 # 3. Convert the 'tripduration' column to datetime datatype.
# ...

# %%
# 4. Check the datatypes of your columns. 
citibike.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2344224 entries, 0 to 2344223
# Data columns (total 15 columns):
#  #   Column                   Dtype
# ---  ------                   -----
#  0   tripduration             datetime64[ns]
#  1   starttime                object
#  2   stoptime                 object
#  3   start station id         float64
#  4   start station name       object
#  5   start station latitude   float64
#  6   start station longitude  float64
#  7   end station id           float64
#  8   end station name         object
#  9   end station latitude     float64
#  10  end station longitude    float64
#  11  bikeid                   int64
#  12  usertype                 object
#  13  birth year               int64
#  14  gender                   int64
# dtypes: datetime64[ns](1), float64(6), int64(3), object(5)
# memory usage: 268.3+ MB

# %%
citibike.head()
# Out:
#    Unnamed: 0                   tripduration                 starttime  \
# 0           0  1970-01-01 00:00:00.000000393  2019-08-01 00:00:01.4680
# 1           1  1970-01-01 00:00:00.000000627  2019-08-01 00:00:01.9290
# 2           2  1970-01-01 00:00:00.000001132  2019-08-01 00:00:04.0480
# 3           3  1970-01-01 00:00:00.000001780  2019-08-01 00:00:04.1630
# 4           4  1970-01-01 00:00:00.000001517  2019-08-01 00:00:05.4580
#
#                    stoptime  start station id              start station name  \
# 0  2019-08-01 00:06:35.3780             531.0          Forsyth St & Broome St
# 1  2019-08-01 00:10:29.7840             274.0  Lafayette Ave & Fort Greene Pl
# 2  2019-08-01 00:18:56.1650            2000.0        Front St & Washington St
# 3  2019-08-01 00:29:44.7940             479.0                 9 Ave & W 45 St
# 4  2019-08-01 00:25:23.4550            3312.0                 1 Ave & E 94 St
#
#    start station latitude  start station longitude  end station id  \
# ...

# %%
# 5. Export the Dataframe as a new CSV file without the index.
citibike.to_csv(r'C:\Users\clava\bikesharing\201908-citibike-tripdata.csv')
